# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import time
from datetime import datetime 
from config import g_key
from config import weather_api_key

# %%
# Build URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create a set of randomg latitude and longitude combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# create a list [] for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

     # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Create an empty list to hold the weather data.
city_data = []
print("Beggining Data Retrieval      ")
print("------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descript = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_weather_descript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beggining Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | bayji
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | polunochnoye
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | meridian
# Processing Record 7 of Set 1 | pangnirtung
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | mehamn
# Processing Record 10 of Set 1 | cidreira
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | zhanakorgan
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | hede
# Processing Record 15 of Set 1 | nome
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | vila velha
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | zheleznodorozhnyy
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | oerlinghausen
# Processing Record 22 of Set 1 | hervey bay
# Processing Record 23 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 1 | sobolevo
# Processing Record 25 of Set 1 | imbituba
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | geraldton
# Processing Record 29 of Set 1 | laguna
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | aksu
# Processing Record 32 of Set 1 | progreso
# Processing Record 33 of Set 1 | muros
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | khagrachari
# City not found. Skipping...
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | san cristobal
# Processing Record 43 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 44 of Set 1 | tyukhtet
# Processing Record 45 of Set 1 | jacareacanga
# Processing Record 46 of Set 1 | meulaboh
# Processing Record 47 of Set 1 | canatlan
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | adrar
# Processing Record 50 of Set 1 | ensenada
# Processing Record 1 of Set 2 | surgut
# Processing Record 2 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | bambous virieux
# Processing Record 6 of Set 2 | traverse city
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | inhambane
# Processing Record 9 of Set 2 | kargasok
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | poum
# Processing Record 14 of Set 2 | santa rosalia
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | alice springs
# Processing Record 19 of Set 2 | aklavik
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | san quintin
# Processing Record 24 of Set 2 | tirau
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | ixtapa
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | barnaul
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | siavonga
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | sao filipe
# Processing Record 35 of Set 2 | guerrero negro
# Processing Record 36 of Set 2 | vila franca do campo
# Processing Record 37 of Set 2 | ayan
# Processing Record 38 of Set 2 | longyan
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | rincon
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | kruisfontein
# Processing Record 46 of Set 2 | grand gaube
# Processing Record 47 of Set 2 | linjiang
# Processing Record 48 of Set 2 | christchurch
# Processing Record 49 of Set 2 | kudahuvadhoo
# Processing Record 50 of Set 2 | rocha
# Processing Record 1 of Set 3 | kurumkan
# Processing Record 2 of Set 3 | denpasar
# Processing Record 3 of Set 3 | shiyan
# Processing Record 4 of Set 3 | waingapu
# Processing Record 5 of Set 3 | esperance
# Processing Record 6 of Set 3 | sampit
# Processing Record 7 of Set 3 | mount isa
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | kavieng
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | isangel
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | passi
# Processing Record 14 of Set 3 | rudnogorsk
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | leningradskiy
# Processing Record 17 of Set 3 | karratha
# Processing Record 18 of Set 3 | north bend
# Processing Record 19 of Set 3 | boshnyakovo
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | inuvik
# Processing Record 23 of Set 3 | hadgaon
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 28 of Set 3 | safranbolu
# Processing Record 29 of Set 3 | lagoa
# Processing Record 30 of Set 3 | dudinka
# Processing Record 31 of Set 3 | ketchikan
# Processing Record 32 of Set 3 | clinton
# Processing Record 33 of Set 3 | byron bay
# Processing Record 34 of Set 3 | port lincoln
# Processing Record 35 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 3 | kantang
# Processing Record 37 of Set 3 | saskylakh
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | coihaique
# Processing Record 40 of Set 3 | sisimiut
# Processing Record 41 of Set 3 | faya
# Processing Record 42 of Set 3 | college
# Processing Record 43 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 3 | kanye
# Processing Record 45 of Set 3 | asfi
# Processing Record 46 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 3 | pochutla
# Processing Record 48 of Set 3 | touros
# Processing Record 49 of Set 3 | prince rupert
# Processing Record 50 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | saint-joseph
# Processing Record 2 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 4 | tuktoyaktuk
# Processing Record 6 of Set 4 | te anau
# Processing Record 7 of Set 4 | brae
# Processing Record 8 of Set 4 | ganesti
# Processing Record 9 of Set 4 | panama city
# Processing Record 10 of Set 4 | springbok
# Processing Record 11 of Set 4 | castlegar
# Processing Record 12 of Set 4 | berlevag
# Processing Record 13 of Set 4 | durant
# Processing Record 14 of Set 4 | krasnoselkup
# Processing Record 15 of Set 4 | tiznit
# Processing Record 16 of Set 4 | ambon
# Processing Record 17 of Set 4 | abashiri
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | hilo
# Processing Record 20 of Set 4 | kapaa
# Processing Record 21 of Set 4 | umm kaddadah
# Processing Record 22 of Set 4 | sabang
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | valley city
# Processing Record 25 of Set 4 | samarkand
# Processing Record 26 of Set 4 | reforma
# Processing Record 27 of Set 4 | barra do garcas
# Processing Record 28 of Set 4 | aliwal north
# Processing Record 29 of Set 4 | tezu
# Processing Record 30 of Set 4 | kloulklubed
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | cserszegtomaj
# Processing Record 33 of Set 4 | grafton
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 35 of Set 4 | butaritari
# Processing Record 36 of Set 4 | novopokrovka
# Processing Record 37 of Set 4 | khatanga
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | rudbar
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | hofn
# Processing Record 42 of Set 4 | necochea
# Processing Record 43 of Set 4 | pingliang
# Processing Record 44 of Set 4 | lufilufi
# Processing Record 45 of Set 4 | ust-nera
# Processing Record 46 of Set 4 | moose factory
# Processing Record 47 of Set 4 | ati
# Processing Record 48 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 4 | saint-francois
# Processing Record 50 of Set 4 | kalmunai
# Processing Record 1 of Set 5 | nicolae balcescu
# Processing Record 2 of Set 5 | riviere-du-loup
# Processing Record 3 of Set 5 | batagay-alyta
# Processing Record 4 of Set 5 | tual
# Processing Record 5 of Set 5 | qaanaaq
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 5 | lima
# Processing Record 9 of Set 5 | atherton
# Processing Record 10 of Set 5 | mandalgovi
# Processing Record 11 of Set 5 | nouadhibou
# Processing Record 12 of Set 5 | carnarvon
# Processing Record 13 of Set 5 | kailua
# Processing Record 14 of Set 5 | katsuura
# Processing Record 15 of Set 5 | picton
# Processing Record 16 of Set 5 | myaundzha
# Processing Record 17 of Set 5 | jamestown
# Processing Record 18 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 5 | khorixas
# Processing Record 20 of Set 5 | davila
# Processing Record 21 of Set 5 | saint anthony
# Processing Record 22 of Set 5 | airai
# Processing Record 23 of Set 5 | maksatikha
# Processing Record 24 of Set 5 | east london
# Processing Record 25 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 5 | bastrop
# Processing Record 27 of Set 5 | barahona
# Processing Record 28 of Set 5 | pisco
# Processing Record 29 of Set 5 | sayyan
# Processing Record 30 of Set 5 | datong
# Processing Record 31 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 5 | georgetown
# Processing Record 33 of Set 5 | marrakesh
# Processing Record 34 of Set 5 | talnakh
# Processing Record 35 of Set 5 | manokwari
# Processing Record 36 of Set 5 | trabzon
# Processing Record 37 of Set 5 | fort nelson
# Processing Record 38 of Set 5 | senhor do bonfim
# Processing Record 39 of Set 5 | gunjur
# Processing Record 40 of Set 5 | perpignan
# Processing Record 41 of Set 5 | juneau
# Processing Record 42 of Set 5 | kavaratti
# Processing Record 43 of Set 5 | olafsvik
# Processing Record 44 of Set 5 | caravelas
# Processing Record 45 of Set 5 | kuruman
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | sulangan
# Processing Record 48 of Set 5 | avera
# Processing Record 49 of Set 5 | areka
# Processing Record 50 of Set 5 | sioux lookout
# Processing Record 1 of Set 6 | alugan
# Processing Record 2 of Set 6 | henties bay
# Processing Record 3 of Set 6 | elk point
# Processing Record 4 of Set 6 | chiredzi
# Processing Record 5 of Set 6 | price
# Processing Record 6 of Set 6 | awjilah
# Processing Record 7 of Set 6 | marystown
# Processing Record 8 of Set 6 | waipawa
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | marsh harbour
# Processing Record 11 of Set 6 | kerman
# Processing Record 12 of Set 6 | guilin
# Processing Record 13 of Set 6 | luganville
# Processing Record 14 of Set 6 | hualmay
# Processing Record 15 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | san antonio
# Processing Record 17 of Set 6 | dawei
# Processing Record 18 of Set 6 | fayaoue
# Processing Record 19 of Set 6 | saldanha
# Processing Record 20 of Set 6 | benguela
# Processing Record 21 of Set 6 | xining
# Processing Record 22 of Set 6 | qinhuangdao
# Processing Record 23 of Set 6 | los llanos de aridane
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | saint george
# Processing Record 26 of Set 6 | tuatapere
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | kleck
# City not found. Skipping...
# Processing Record 29 of Set 6 | kaitangata
# Processing Record 30 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 6 | gondanglegi
# Processing Record 32 of Set 6 | nishihara
# Processing Record 33 of Set 6 | raudeberg
# Processing Record 34 of Set 6 | les cayes
# Processing Record 35 of Set 6 | chimoio
# Processing Record 36 of Set 6 | kulhudhuffushi
# Processing Record 37 of Set 6 | hun
# Processing Record 38 of Set 6 | bandarbeyla
# Processing Record 39 of Set 6 | superior
# Processing Record 40 of Set 6 | sorland
# Processing Record 41 of Set 6 | vao
# Processing Record 42 of Set 6 | padang
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | zhigansk
# Processing Record 45 of Set 6 | narsaq
# Processing Record 46 of Set 6 | mattru
# Processing Record 47 of Set 6 | salalah
# Processing Record 48 of Set 6 | santa isabel
# Processing Record 49 of Set 6 | villagarzon
# Processing Record 50 of Set 6 | saint-pierre
# Processing Record 1 of Set 7 | lipin bor
# Processing Record 2 of Set 7 | kisarazu
# Processing Record 3 of Set 7 | shimoda
# Processing Record 4 of Set 7 | kahului
# Processing Record 5 of Set 7 | grenfell
# Processing Record 6 of Set 7 | areosa
# Processing Record 7 of Set 7 | bandundu
# Processing Record 8 of Set 7 | illapel
# Processing Record 9 of Set 7 | soyo
# Processing Record 10 of Set 7 | nuuk
# Processing Record 11 of Set 7 | abu samrah
# Processing Record 12 of Set 7 | mackay
# Processing Record 13 of Set 7 | alofi
# Processing Record 14 of Set 7 | ayr
# Processing Record 15 of Set 7 | jalu
# Processing Record 16 of Set 7 | norman wells
# Processing Record 17 of Set 7 | wagrowiec
# Processing Record 18 of Set 7 | cockburn town
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | megion
# Processing Record 21 of Set 7 | moba
# Processing Record 22 of Set 7 | provideniya
# Processing Record 23 of Set 7 | hamina
# Processing Record 24 of Set 7 | svetlyy
# Processing Record 25 of Set 7 | marshall
# Processing Record 26 of Set 7 | zeya
# Processing Record 27 of Set 7 | bonavista
# Processing Record 28 of Set 7 | severodvinsk
# Processing Record 29 of Set 7 | sukumo
# Processing Record 30 of Set 7 | exeter
# Processing Record 31 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 7 | danjiangkou
# Processing Record 33 of Set 7 | axim
# Processing Record 34 of Set 7 | maldonado
# Processing Record 35 of Set 7 | katwa
# Processing Record 36 of Set 7 | haines junction
# Processing Record 37 of Set 7 | gernsheim
# Processing Record 38 of Set 7 | ucluelet
# Processing Record 39 of Set 7 | quesnel
# Processing Record 40 of Set 7 | cerrito
# Processing Record 41 of Set 7 | clyde river
# Processing Record 42 of Set 7 | novo aripuana
# Processing Record 43 of Set 7 | boa esperanca do sul
# Processing Record 44 of Set 7 | merauke
# Processing Record 45 of Set 7 | suntar
# Processing Record 46 of Set 7 | faanui
# Processing Record 47 of Set 7 | mareeba
# Processing Record 48 of Set 7 | tommot
# Processing Record 49 of Set 7 | quatre cocos
# Processing Record 50 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 1 of Set 8 | grand baie
# Processing Record 2 of Set 8 | krasnyy chikoy
# Processing Record 3 of Set 8 | rio gallegos
# Processing Record 4 of Set 8 | marzuq
# Processing Record 5 of Set 8 | ossora
# Processing Record 6 of Set 8 | bemidji
# Processing Record 7 of Set 8 | moron
# Processing Record 8 of Set 8 | lavrentiya
# Processing Record 9 of Set 8 | esmeraldas
# Processing Record 10 of Set 8 | half moon bay
# Processing Record 11 of Set 8 | kholodnyy
# Processing Record 12 of Set 8 | coahuayana
# Processing Record 13 of Set 8 | naftalan
# Processing Record 14 of Set 8 | sumenep
# Processing Record 15 of Set 8 | madinat sittah uktubar
# Processing Record 16 of Set 8 | nargana
# Processing Record 17 of Set 8 | camacha
# Processing Record 18 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 8 | berezovyy
# Processing Record 20 of Set 8 | viedma
# Processing Record 21 of Set 8 | rabo de peixe
# Processing Record 22 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 8 | severo-kurilsk
# Processing Record 24 of Set 8 | sassandra
# Processing Record 25 of Set 8 | uinskoye
# Processing Record 26 of Set 8 | pushkino
# Processing Record 27 of Set 8 | mazyr
# Processing Record 28 of Set 8 | alihe
# Processing Record 29 of Set 8 | aberdeen
# Processing Record 30 of Set 8 | cuamba
# Processing Record 31 of Set 8 | epe
# Processing Record 32 of Set 8 | borlange
# City not found. Skipping...
# Processing Record 33 of Set 8 | richards bay
# Processing Record 34 of Set 8 | setermoen
# Processing Record 35 of Set 8 | kontagora
# Processing Record 36 of Set 8 | los altos
# Processing Record 37 of Set 8 | cayenne
# Processing Record 38 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 8 | matagami
# Processing Record 40 of Set 8 | amahai
# Processing Record 41 of Set 8 | el dorado
# Processing Record 42 of Set 8 | asau
# Processing Record 43 of Set 8 | socorro
# Processing Record 44 of Set 8 | khor
# Processing Record 45 of Set 8 | aquin
# Processing Record 46 of Set 8 | mabaruma
# Processing Record 47 of Set 8 | kargil
# Processing Record 48 of Set 8 | kuytun
# Processing Record 49 of Set 8 | constitucion
# Processing Record 50 of Set 8 | villa guerrero
# Processing Record 1 of Set 9 | beringovskiy
# Processing Record 2 of Set 9 | deniliquin
# Processing Record 3 of Set 9 | reefton
# City not found. Skipping...
# Processing Record 4 of Set 9 | vilhena
# Processing Record 5 of Set 9 | ariquemes
# Processing Record 6 of Set 9 | anahuac
# Processing Record 7 of Set 9 | kitob
# Processing Record 8 of Set 9 | koundara
# Processing Record 9 of Set 9 | roald
# Processing Record 10 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 11 of Set 9 | korla
# Processing Record 12 of Set 9 | matamoros
# Processing Record 13 of Set 9 | odweyne
# Processing Record 14 of Set 9 | wolmaranstad
# City not found. Skipping...
# Processing Record 15 of Set 9 | port hedland
# Processing Record 16 of Set 9 | husavik
# Processing Record 17 of Set 9 | itarema
# Processing Record 18 of Set 9 | cairns
# Processing Record 19 of Set 9 | karaman
# Processing Record 20 of Set 9 | mayo
# Processing Record 21 of Set 9 | deputatskiy
# Processing Record 22 of Set 9 | anadyr
# Processing Record 23 of Set 9 | tambura
# Processing Record 24 of Set 9 | puerto escondido
# Processing Record 25 of Set 9 | bloemfontein
# Processing Record 26 of Set 9 | hami
# Processing Record 27 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 28 of Set 9 | mumford
# Processing Record 29 of Set 9 | oruro
# Processing Record 30 of Set 9 | kochinda
# Processing Record 31 of Set 9 | alyangula
# Processing Record 32 of Set 9 | ode
# Processing Record 33 of Set 9 | lebanon
# Processing Record 34 of Set 9 | vredendal
# Processing Record 35 of Set 9 | vostok
# Processing Record 36 of Set 9 | dingle
# Processing Record 37 of Set 9 | bontang
# Processing Record 38 of Set 9 | micheweni
# Processing Record 39 of Set 9 | flinders
# Processing Record 40 of Set 9 | ewa beach
# Processing Record 41 of Set 9 | baturaja
# Processing Record 42 of Set 9 | robertsport
# Processing Record 43 of Set 9 | port hardy
# Processing Record 44 of Set 9 | kapfenberg
# Processing Record 45 of Set 9 | iisalmi
# Processing Record 46 of Set 9 | kieta
# Processing Record 47 of Set 9 | carver
# Processing Record 48 of Set 9 | broome
# Processing Record 49 of Set 9 | la ronge
# Processing Record 50 of Set 9 | la rioja
# Processing Record 1 of Set 10 | chifeng
# Processing Record 2 of Set 10 | gat
# Processing Record 3 of Set 10 | botwood
# Processing Record 4 of Set 10 | lircay
# Processing Record 5 of Set 10 | champerico
# Processing Record 6 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 10 | trelew
# Processing Record 8 of Set 10 | primorsk
# Processing Record 9 of Set 10 | englewood
# Processing Record 10 of Set 10 | barguzin
# Processing Record 11 of Set 10 | merrill
# Processing Record 12 of Set 10 | broken hill
# Processing Record 13 of Set 10 | yala
# Processing Record 14 of Set 10 | lusambo
# Processing Record 15 of Set 10 | guiratinga
# Processing Record 16 of Set 10 | vila
# Processing Record 17 of Set 10 | bangassou
# Processing Record 18 of Set 10 | lyuban
# Processing Record 19 of Set 10 | bako
# Processing Record 20 of Set 10 | xai-xai
# Processing Record 21 of Set 10 | alibag
# Processing Record 22 of Set 10 | alexandria
# Processing Record 23 of Set 10 | susteren
# Processing Record 24 of Set 10 | muzhi
# Processing Record 25 of Set 10 | oranjemund
# Processing Record 26 of Set 10 | doka
# Processing Record 27 of Set 10 | la asuncion
# Processing Record 28 of Set 10 | portland
# Processing Record 29 of Set 10 | labuhan
# Processing Record 30 of Set 10 | nokaneng
# Processing Record 31 of Set 10 | kamaishi
# Processing Record 32 of Set 10 | linxia
# Processing Record 33 of Set 10 | sinfra
# Processing Record 34 of Set 10 | jaciara
# Processing Record 35 of Set 10 | marfino
# Processing Record 36 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 38 of Set 10 | svetlogorsk
# Processing Record 39 of Set 10 | kyzyl-suu
# Processing Record 40 of Set 10 | pitkyaranta
# Processing Record 41 of Set 10 | sadat
# Processing Record 42 of Set 10 | westport
# Processing Record 43 of Set 10 | mogzon
# Processing Record 44 of Set 10 | ola
# Processing Record 45 of Set 10 | danshui
# Processing Record 46 of Set 10 | hobyo
# Processing Record 47 of Set 10 | vasto
# Processing Record 48 of Set 10 | dunedin
# Processing Record 49 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 10 | srednekolymsk
# Processing Record 1 of Set 11 | antofagasta
# Processing Record 2 of Set 11 | namatanai
# Processing Record 3 of Set 11 | abalak
# Processing Record 4 of Set 11 | gorkovskoye
# City not found. Skipping...
# Processing Record 5 of Set 11 | the pas
# Processing Record 6 of Set 11 | bojnurd
# Processing Record 7 of Set 11 | kutum
# Processing Record 8 of Set 11 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 9 of Set 11 | san isidro
# Processing Record 10 of Set 11 | lang suan
# Processing Record 11 of Set 11 | tilichiki
# Processing Record 12 of Set 11 | mount gambier
# Processing Record 13 of Set 11 | shubarshi
# Processing Record 14 of Set 11 | challapata
# Processing Record 15 of Set 11 | vestmanna
# Processing Record 16 of Set 11 | azrow
# City not found. Skipping...
# Processing Record 17 of Set 11 | hof
# Processing Record 18 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 19 of Set 11 | aasiaat
# Processing Record 20 of Set 11 | nantucket
# Processing Record 21 of Set 11 | lakselv
# Processing Record 22 of Set 11 | kaman
# Processing Record 23 of Set 11 | mugur-aksy
# Processing Record 24 of Set 11 | sitka
# Processing Record 25 of Set 11 | vale da amoreira
# Processing Record 26 of Set 11 | sao joao da barra
# Processing Record 27 of Set 11 | yar-sale
# Processing Record 28 of Set 11 | sistranda
# Processing Record 29 of Set 11 | nara
# Processing Record 30 of Set 11 | pombas
# Processing Record 31 of Set 11 | lake charles
# Processing Record 32 of Set 11 | kudymkar
# Processing Record 33 of Set 11 | dillon
# Processing Record 34 of Set 11 | tornio
# Processing Record 35 of Set 11 | itapage
# Processing Record 36 of Set 11 | acurenam
# Processing Record 37 of Set 11 | havoysund
# Processing Record 38 of Set 11 | mutum
# Processing Record 39 of Set 11 | sola
# Processing Record 40 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 11 | sozimskiy
# Processing Record 42 of Set 11 | waitati
# Processing Record 43 of Set 11 | tawzar
# City not found. Skipping...
# Processing Record 44 of Set 11 | sibolga
# Processing Record 45 of Set 11 | tucuma
# Processing Record 46 of Set 11 | palmerston north
# Processing Record 47 of Set 11 | plastun
# Processing Record 48 of Set 11 | egvekinot
# Processing Record 49 of Set 11 | goderich
# Processing Record 50 of Set 11 | yaring
# Processing Record 1 of Set 12 | rawson
# Processing Record 2 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 12 | oktyabrskiy
# Processing Record 4 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 12 | yershov
# Processing Record 6 of Set 12 | tonder
# Processing Record 7 of Set 12 | ugoofaaru
# Processing Record 8 of Set 12 | jasper
# Processing Record 9 of Set 12 | atar
# Processing Record 10 of Set 12 | sept-iles
# Processing Record 11 of Set 12 | san vicente
# Processing Record 12 of Set 12 | itaituba
# Processing Record 13 of Set 12 | san patricio
# Processing Record 14 of Set 12 | bonthe
# Processing Record 15 of Set 12 | port blair
# Processing Record 16 of Set 12 | carutapera
# Processing Record 17 of Set 12 | basco
# Processing Record 18 of Set 12 | el alto
# Processing Record 19 of Set 12 | borogontsy
# Processing Record 20 of Set 12 | nabire
# Processing Record 21 of Set 12 | buraydah
# Processing Record 22 of Set 12 | troitskoye
# Processing Record 23 of Set 12 | coos bay
# Processing Record 24 of Set 12 | araouane
# Processing Record 25 of Set 12 | murdochville
# Processing Record 26 of Set 12 | kathu
# Processing Record 27 of Set 12 | kupang
# Processing Record 28 of Set 12 | uk
# City not found. Skipping...
# Processing Record 29 of Set 12 | yaan
# Processing Record 30 of Set 12 | bathsheba
# Processing Record 31 of Set 12 | walvis bay
# Processing Record 32 of Set 12 | westerland
# Processing Record 33 of Set 12 | cartagena
# Processing Record 34 of Set 12 | samarai
# Processing Record 35 of Set 12 | fare
# Processing Record 36 of Set 12 | port-gentil
# Processing Record 37 of Set 12 | monrovia
# Processing Record 38 of Set 12 | launceston
# Processing Record 39 of Set 12 | kozan
# Processing Record 40 of Set 12 | porbandar
# Processing Record 41 of Set 12 | masallatah
# Processing Record 42 of Set 12 | todos santos
# Processing Record 43 of Set 12 | hirara
# Processing Record 44 of Set 12 | erzin
# Processing Record 45 of Set 12 | panshi
# Processing Record 46 of Set 12 | tessalit
# Processing Record 47 of Set 12 | marawi
# Processing Record 48 of Set 12 | verkhoyansk
# Processing Record 49 of Set 12 | bac lieu
# Processing Record 50 of Set 12 | zyryanka
# Processing Record 1 of Set 13 | zagarolo
# Processing Record 2 of Set 13 | hovd
# Processing Record 3 of Set 13 | buala
# Processing Record 4 of Set 13 | pedernales
# Processing Record 5 of Set 13 | gauribidanur
# Processing Record 6 of Set 13 | kuala terengganu
# Processing Record 7 of Set 13 | notre-dame-du-lac
# Processing Record 8 of Set 13 | lyngseidet
# Processing Record 9 of Set 13 | boyolangu
# Processing Record 10 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 11 of Set 13 | omboue
# Processing Record 12 of Set 13 | aksha
# Processing Record 13 of Set 13 | jhang
# Processing Record 14 of Set 13 | paamiut
# Processing Record 15 of Set 13 | port-cartier
# Processing Record 16 of Set 13 | obigarm
# Processing Record 17 of Set 13 | manbij
# Processing Record 18 of Set 13 | maumere
# Processing Record 19 of Set 13 | antalaha
# Processing Record 20 of Set 13 | dryden
# Processing Record 21 of Set 13 | bronnoysund
# Processing Record 22 of Set 13 | khandyga
# Processing Record 23 of Set 13 | orlik
# Processing Record 24 of Set 13 | maba
# Processing Record 25 of Set 13 | yertsevo
# Processing Record 26 of Set 13 | tulun
# Processing Record 27 of Set 13 | salinopolis
# Processing Record 28 of Set 13 | san andres
# Processing Record 29 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 30 of Set 13 | navirai
# Processing Record 31 of Set 13 | zacatepec
# Processing Record 32 of Set 13 | teya
# Processing Record 33 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 13 | barbate
# Processing Record 35 of Set 13 | takoradi
# Processing Record 36 of Set 13 | taoudenni
# Processing Record 37 of Set 13 | puro
# Processing Record 38 of Set 13 | mallaig
# Processing Record 39 of Set 13 | maceio
# Processing Record 40 of Set 13 | puri
# Processing Record 41 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 13 | sebastian
# Processing Record 43 of Set 13 | keti bandar
# Processing Record 44 of Set 13 | vaitape
# Processing Record 45 of Set 13 | mahibadhoo
# Processing Record 46 of Set 13 | moquegua
# Processing Record 47 of Set 13 | claudio
# Processing Record 48 of Set 13 | hambantota
# Processing Record 49 of Set 13 | tambo
# Processing Record 50 of Set 13 | maraa
# Processing Record 1 of Set 14 | northam
# Processing Record 2 of Set 14 | agropoli
# Processing Record 3 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 4 of Set 14 | bubaque
# Processing Record 5 of Set 14 | havelock
# Processing Record 6 of Set 14 | sarkand
# Processing Record 7 of Set 14 | waqqas
# Processing Record 8 of Set 14 | mogadishu
# Processing Record 9 of Set 14 | zhigalovo
# Processing Record 10 of Set 14 | rehoboth
# Processing Record 11 of Set 14 | tiarei
# Processing Record 12 of Set 14 | saurimo
# Processing Record 13 of Set 14 | victor harbor
# Processing Record 14 of Set 14 | voh
# Processing Record 15 of Set 14 | podor
# Processing Record 16 of Set 14 | sannat
# Processing Record 17 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 14 | mwinilunga
# Processing Record 19 of Set 14 | lhokseumawe
# Processing Record 20 of Set 14 | eureka
# Processing Record 21 of Set 14 | bodaybo
# Processing Record 22 of Set 14 | codajas
# Processing Record 23 of Set 14 | kungurtug
# Processing Record 24 of Set 14 | olgod
# Processing Record 25 of Set 14 | tayoltita
# Processing Record 26 of Set 14 | tir pol
# City not found. Skipping...
# Processing Record 27 of Set 14 | groningen
# Processing Record 28 of Set 14 | oconomowoc
# Processing Record 29 of Set 14 | yenagoa
# Processing Record 30 of Set 14 | turayf
# Processing Record 31 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 32 of Set 14 | pasighat
# Processing Record 33 of Set 14 | okha
# Processing Record 34 of Set 14 | winnetka
# Processing Record 35 of Set 14 | pevek
# Processing Record 36 of Set 14 | iberia
# Processing Record 37 of Set 14 | anloga
# Processing Record 38 of Set 14 | hellin
# Processing Record 39 of Set 14 | kholmogory
# Processing Record 40 of Set 14 | chapais
# Processing Record 41 of Set 14 | mandera
# Processing Record 42 of Set 14 | saint-augustin
# Processing Record 43 of Set 14 | rumoi
# Processing Record 44 of Set 14 | kiunga
# Processing Record 45 of Set 14 | ostrovnoy
# Processing Record 46 of Set 14 | zhezkazgan
# Processing Record 47 of Set 14 | naze
# Processing Record 48 of Set 14 | tautira
# Processing Record 49 of Set 14 | markova
# Processing Record 50 of Set 14 | noumea
# Processing Record 1 of Set 15 | sambava
# Processing Record 2 of Set 15 | sitges
# Processing Record 3 of Set 15 | acarau
# Processing Record 4 of Set 15 | birao
# Processing Record 5 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 6 of Set 15 | resistencia
# Processing Record 7 of Set 15 | dalianwan
# Processing Record 8 of Set 15 | mackenzie
# Processing Record 9 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 10 of Set 15 | zabol
# Processing Record 11 of Set 15 | nicoya
# Processing Record 12 of Set 15 | kilindoni
# Processing Record 13 of Set 15 | millinocket
# Processing Record 14 of Set 15 | hvide sande
# Processing Record 15 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 16 of Set 15 | hit
# Processing Record 17 of Set 15 | ballina
# Processing Record 18 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 19 of Set 15 | nogliki
# Processing Record 20 of Set 15 | partur
# Processing Record 21 of Set 15 | salamiyah
# Processing Record 22 of Set 15 | norton
# Processing Record 23 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 15 | mnogovershinnyy
# Processing Record 25 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 15 | sakaiminato
# Processing Record 27 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 28 of Set 15 | tolaga bay
# Processing Record 29 of Set 15 | lorengau
# Processing Record 30 of Set 15 | aden
# Processing Record 31 of Set 15 | yantai
# Processing Record 32 of Set 15 | singaraja
# Processing Record 33 of Set 15 | plettenberg bay
# Processing Record 34 of Set 15 | hendek
# Processing Record 35 of Set 15 | marang
# Processing Record 36 of Set 15 | lasa
# Processing Record 37 of Set 15 | majenang
# Processing Record 38 of Set 15 | atambua
# Processing Record 39 of Set 15 | payo
# Processing Record 40 of Set 15 | neon karlovasion
# Processing Record 41 of Set 15 | thanyaburi
# Processing Record 42 of Set 15 | usinsk
# Processing Record 43 of Set 15 | mbacke
# City not found. Skipping...
# Processing Record 44 of Set 15 | southwick
# Processing Record 45 of Set 15 | dzhebariki-khaya
# Processing Record 46 of Set 15 | tsabong
# Processing Record 47 of Set 15 | santo augusto
# Processing Record 48 of Set 15 | rolla
# Processing Record 49 of Set 15 | palu
# Processing Record 50 of Set 15 | mingaora
# Processing Record 1 of Set 16 | abu kamal
# Processing Record 2 of Set 16 | waddan
# Processing Record 3 of Set 16 | marion
# Processing Record 4 of Set 16 | santa rosa
# Processing Record 5 of Set 16 | amarillo
# Processing Record 6 of Set 16 | kysyl-syr
# Processing Record 7 of Set 16 | huarmey
# Processing Record 8 of Set 16 | lakheri
# Processing Record 9 of Set 16 | coquimbo
# Processing Record 10 of Set 16 | twentynine palms
# Processing Record 11 of Set 16 | grenaa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bayji  34.9311   43.4870     67.87        62          95
# 1       Mataura -46.1927  168.8643     53.01        98         100
# 2  Polunochnoye  60.8697   60.4153     16.45        94          87
# 3     Mahebourg -20.4081   57.7000     80.60        89          75
# 4      Meridian  43.6121 -116.3915     44.01        75           1
# 5   Pangnirtung  66.1451  -65.7125    -23.80        62          40
# 6   Port Alfred -33.5906   26.8910     69.44        72          20
# 7        Mehamn  71.0357   27.8492     32.00        93          90
# 8      Cidreira -30.1811  -50.2056     71.74        92         100
# 9   Zhanakorgan  43.9098   67.2495     38.66        57          20
#
#    Wind Speed Country                 Date Current Description
# 0       12.21      IQ  2021-03-23 17:30:36     overcast clouds
# 1        1.43      NZ  2021-03-23 17:26:29     overcast clouds
# 2        4.74      RU  2021-03-23 17:30:37     overcast clouds
# 3        6.91      MU  2021-03-23 17:30:37       broken clouds
# 4       18.41      US  2021-03-23 17:30:38           clear sky
# 5        3.44      CA  2021-03-23 17:30:38    scattered clouds
# 6       18.01      ZA  2021-03-23 17:30:38          few clouds
# 7       34.52      NO  2021-03-23 17:30:39                snow
# 8        2.98      BR  2021-03-23 17:30:39     overcast clouds
# 9        8.25      KZ  2021-03-23 17:30:40          few clouds

# %%
# Create new varialbel with correct column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# assign old DF = to old DF[new_varaible]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bayji      IQ  34.9311   43.4870     67.87        62          95
# 1       Mataura      NZ -46.1927  168.8643     53.01        98         100
# 2  Polunochnoye      RU  60.8697   60.4153     16.45        94          87
# 3     Mahebourg      MU -20.4081   57.7000     80.60        89          75
# 4      Meridian      US  43.6121 -116.3915     44.01        75           1
# 5   Pangnirtung      CA  66.1451  -65.7125    -23.80        62          40
# 6   Port Alfred      ZA -33.5906   26.8910     69.44        72          20
# 7        Mehamn      NO  71.0357   27.8492     32.00        93          90
# 8      Cidreira      BR -30.1811  -50.2056     71.74        92         100
# 9   Zhanakorgan      KZ  43.9098   67.2495     38.66        57          20
#
#    Wind Speed Current Description
# 0       12.21     overcast clouds
# 1        1.43     overcast clouds
# 2        4.74     overcast clouds
# 3        6.91       broken clouds
# 4       18.41           clear sky
# 5        3.44    scattered clouds
# 6       18.01          few clouds
# 7       34.52                snow
# 8        2.98     overcast clouds
# 9        8.25          few clouds

# %%
# Create an output file as a CSV
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data inot a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
